# %% [markdown]
# # Today's topics
# We will try to find out which phenotypic traits are associated with genetic markers in the BXD mouse population. This will allow us to make statements about the level of heritability of several traits as well as help us identify candidate genes responsible for specific traits.
#
# There are several types of studies relevant in this context:
#
# * Single gene association studies
# * Genome wide association studies
# * Phenome wide association studies

# %% [markdown]
# # GWAS background

# %% [markdown]
# http://www.ncbi.nlm.nih.gov/pmc/articles/PMC2736153/ contains information about how to use genenetwork.org to find coat color phenotype and correlate that to expression levels

# %% [markdown]
# # Useful Resources

# %% [markdown]
# ## Packages
#
# ### R
# * [Matrix eQTL](http://www.bios.unc.edu/research/genomic_software/Matrix_eQTL/)
# * [GWAS Tools](http://bioconductor.org/packages/release/bioc/html/GWASTools.html)
# * [GenABEL](http://www.genabel.org/)
#
#
# ### Python
# * [llmlite](http://kbroman.org/lmmlite/assets/compare2pylmm.html)
# * [pylmm](http://genetics.cs.ucla.edu/pylmm/)
# * [fstlmm](http://lomereiter.github.io/2015/02/16/lmm_cov.html)
# * [pyGWAS](https://github.com/timeu/PyGWAS)
# * [krux](https://github.com/tmichoel/krux/blob/master/python/kruX.py)

# %% [markdown]
# ## Books
# * [James, Witten, Hastie, Tibshirani, An Introduction to Statistical Learning, Springer Texts, 2013](http://www-bcf.usc.edu/~gareth/ISL/)
# * [MacKay, Information Theory, Inference, and Learning Algorithms, Cambridge University Press, 2005](http://www.inference.phy.cam.ac.uk/itila/book.html)
#
#
# ## Tutorials
# * [Logistic regression](http://blog.yhat.com/posts/logistic-regression-and-python.html)
# * [Linear regression](http://www.dataschool.io/linear-regression-in-python/)

# %% [markdown]
# # Load data
# Before you can work with the data you have to load it and tidy it up a bit. This includes filtering rows with missing values, making sure that numeric columns are indeed of a numeric data type in the data frame, ...

# %% [markdown]
# ## Load genotype data as pandas dataframe
# Follow the same procedure as done yesterday. You do not have to download the file again, but can load it from your originally stored location.

# %%
import os
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import stats
from scipy.stats import chi2_contingency, fisher_exact
from collections import Counter 

geno_data = '../files_day_two/aad0189_DataFileS4.txt'

# %% [markdown]
# ## Subtask: Set SNP-ID column as index

# %%
# read in genotype data
geno_df = pd.read_csv(geno_data, sep='\t', comment='@', index_col="Locus")
geno_df
# Out:
#                 Chr      cM          Mb BXD1 BXD2 BXD5 BXD6 BXD8 BXD9 BXD11  \
# Locus
# rs6269442         1   0.000    3.482275    B    B    D    D    D    B     B
# rs6365999         1   0.000    4.811062    B    B    D    D    D    B     B
# rs6376963         1   0.895    5.008089    B    B    D    D    D    B     B
# rs3677817         1   1.185    5.176058    B    B    D    D    D    B     B
# rs8236463         1   2.081    5.579193    B    B    D    D    D    B     D
# rs6333200         1   2.081    6.217921    B    B    D    D    D    B     D
# rs6298633         1   2.367    6.820241    B    B    D    D    D    B     D
# rs6241531         1   2.367    9.995925    B    B    D    D    D    B     D
# rs6360236         1   3.263   11.073904    B    B    D    D    D    B     D
# rs3722996         1   3.263   11.259432    B    B    D    D    D    B     D
# D1Mit1            1   3.549   11.505582    B    B    D    D    D    B     D
# D1Mit294          1   3.836   11.731387    B    B    D    D    D    B     D
# rs13475728        1   3.836   12.711280    B    B    D    D    D    B     D
# rs3655978         1   5.797   13.373070    B    B    B    D    D    B     D
# rs3654866         1   5.797   13.697098    B    B    B    D    D    B     D
# rs3669485         1   6.083   13.975252    B    B    B    D    D    B     D
# rs3713198         1   6.083   14.464944    B    B    B    D    D    B     D
# rs6291839         1   6.675   14.787217    B    B    B    D    D    B     D
# rs13475735        1   6.675   14.977874    B    B    B    D    D    B     D
# rs3088964         1   6.962   15.196882    B    B    B    D    D    B     D
# rs13475737        1   6.962   15.444839    B    B    B    D    D    B     D
# rs3678179         1   7.248   15.498263    B    B    B    D    D    B     D
# rs6201380         1   7.248   15.801731    B    B    B    D    D    B     D
# gnf01.013.065     1   7.833   16.119466    B    B    B    D    D    B     D
# CEL-1_16893098    1   7.833   16.714342    B    B    B    D    D    B     D
# rs13475745        1   8.119   17.297960    B    B    B    D    D    B     D
# CEL-1_18376533    1   8.406   18.158832    B    B    B    D    D    B     D
# rs13475747        1   8.692   18.595689    B    B    B    D    D    B     D
# rs13475748        1   8.692   18.911761    B    B    B    D    D    B     D
# rs3670611         1   9.588   20.623897    D    B    B    D    D    B     D
# ...              ..     ...         ...  ...  ...  ...  ...  ...  ...   ...
# CEL-X_106858553   X  40.099  112.637353    B    B    B    D    B    B     B
# CEL-X_108186660   X  40.386  113.965459    B    B    B    D    B    B     B
# rs6205221         X  41.963  126.830238    B    B    B    D    B    B     B
# rs6387944         X  42.250  127.009266    B    B    B    D    B    B     B
# rs13483992        X  42.250  127.180024    B    B    B    D    B    B     B
# rs6221690         X  42.835  127.572283    B    B    B    D    B    B     B
# CEL-X_121796581   X  42.835  128.323970    B    B    B    D    B    B     B
# rs13484003        X  45.993  130.138455    B    B    B    D    B    B     B
# rs3702256         X  45.993  131.483756    B    B    B    D    B    B     B
# rs13484013        X  46.280  132.120931    B    B    B    D    B    B     B
# CEL-X_125736335   X  46.280  132.263711    B    B    B    D    B    B     B
# rs13484015        X  46.865  132.663400    B    B    B    D    B    B     B
# rs3697198         X  46.865  132.751196    B    B    B    D    B    B     B
# gnfX.116.876      X  47.760  133.125032    B    B    B    D    B    D     B
# rs13484018        X  48.047  133.329156    B    B    B    D    B    D     B
# rs13484024        X  48.047  134.541556    B    B    B    D    B    D     B
# gnfX.118.600      X  48.632  134.859902    B    B    B    D    B    D     B
# rs13484030        X  48.918  135.887116    B    B    B    D    B    D     B
# rs13484060        X  59.198  143.400776    B    B    B    B    B    D     B
# DXMit10           X  62.903  147.758346    B    B    B    U    B    D     B
# CEL-X_143438541   X  64.917  149.985631    B    B    B    B    B    D     B
# CEL-X_143595976   X  66.475  150.143066    B    B    B    B    B    D     B
# rs13484097        X  68.033  154.738280    B    B    B    B    B    D     B
# gnfX.141.820      X  70.313  158.023553    B    B    B    B    B    B     B
# CEL-X_154048891   X  70.905  160.516968    B    B    B    B    B    B     B
# CEL-X_154259201   X  71.490  160.727278    B    B    B    D    B    B     B
# rs3657281         X  71.776  160.951099    B    B    B    D    B    B     B
# rs13484106        X  71.776  162.637897    B    B    B    D    B    B     B
# gnfX.146.867      X  73.687  163.124562    B    B    B    D    B    B     B
# DXMit223          X  74.279  163.741514    B    B    B    D    B    B     B
#
#                  ...   BXD90 BXD91 BXD93 BXD94 BXD95 BXD98 BXD99 BXD100  \
# Locus            ...
# rs6269442        ...       B     D     B     D     D     B     B      B
# rs6365999        ...       B     D     B     D     D     B     B      B
# rs6376963        ...       B     D     B     D     D     B     B      B
# rs3677817        ...       B     D     B     D     D     B     B      B
# rs8236463        ...       B     D     B     D     D     B     B      B
# rs6333200        ...       B     D     B     D     D     B     B      B
# rs6298633        ...       B     D     B     D     D     B     B      B
# rs6241531        ...       B     D     B     D     D     B     B      B
# rs6360236        ...       B     D     B     D     D     B     B      B
# rs3722996        ...       B     D     B     D     D     B     B      B
# D1Mit1           ...       B     D     B     D     D     B     B      B
# D1Mit294         ...       B     D     B     D     D     B     B      B
# rs13475728       ...       B     D     B     D     D     B     B      B
# rs3655978        ...       B     D     B     D     D     D     B      B
# rs3654866        ...       B     D     B     D     D     D     B      B
# rs3669485        ...       B     D     B     D     D     D     B      B
# rs3713198        ...       B     D     B     D     D     D     B      B
# rs6291839        ...       B     D     B     B     D     D     B      B
# rs13475735       ...       B     D     B     B     D     D     B      B
# rs3088964        ...       B     B     B     B     D     D     B      B
# rs13475737       ...       B     B     B     B     D     D     B      B
# rs3678179        ...       B     B     B     B     D     D     B      B
# rs6201380        ...       B     B     B     B     D     D     B      B
# gnf01.013.065    ...       B     B     B     B     D     D     B      B
# CEL-1_16893098   ...       B     B     B     B     D     D     B      B
# rs13475745       ...       B     B     B     B     D     D     B      B
# CEL-1_18376533   ...       B     B     B     B     D     B     B      B
# rs13475747       ...       B     D     B     B     D     B     B      B
# rs13475748       ...       B     D     B     B     D     B     B      B
# rs3670611        ...       B     D     B     D     D     B     B      B
# ...              ...     ...   ...   ...   ...   ...   ...   ...    ...
# CEL-X_106858553  ...       D     D     D     D     H     H     D      D
# CEL-X_108186660  ...       D     D     D     D     H     H     D      D
# rs6205221        ...       D     D     D     D     B     H     D      D
# rs6387944        ...       D     D     D     D     B     H     D      D
# rs13483992       ...       D     D     D     D     B     H     D      D
# rs6221690        ...       D     D     D     D     B     H     D      D
# CEL-X_121796581  ...       D     D     D     D     B     H     D      D
# rs13484003       ...       D     B     D     D     B     D     D      D
# rs3702256        ...       D     B     D     D     B     D     D      D
# rs13484013       ...       D     B     D     D     B     D     D      D
# CEL-X_125736335  ...       D     B     D     D     B     D     D      D
# rs13484015       ...       D     B     D     D     B     D     D      D
# rs3697198        ...       D     B     D     D     B     D     D      D
# gnfX.116.876     ...       D     B     D     D     B     D     D      D
# rs13484018       ...       D     B     D     D     B     D     D      D
# rs13484024       ...       D     B     D     D     B     D     D      D
# gnfX.118.600     ...       D     B     D     D     B     D     D      D
# rs13484030       ...       D     B     D     D     B     D     D      D
# rs13484060       ...       D     D     B     B     H     D     D      D
# DXMit10          ...       B     B     B     B     H     D     H      H
# CEL-X_143438541  ...       B     B     B     B     H     D     B      B
# CEL-X_143595976  ...       B     B     B     B     H     D     D      B
# rs13484097       ...       B     B     B     D     H     D     D      B
# gnfX.141.820     ...       B     B     D     D     H     D     D      B
# CEL-X_154048891  ...       B     B     D     D     H     D     D      B
# CEL-X_154259201  ...       B     B     D     D     H     D     D      B
# rs3657281        ...       B     B     D     D     H     D     D      B
# rs13484106       ...       B     B     D     D     H     D     D      B
# gnfX.146.867     ...       B     B     D     D     H     D     D      B
# DXMit223         ...       B     B     D     D     H     D     D      B
#
#                 BXD101 BXD102
# Locus
# rs6269442            B      B
# rs6365999            B      U
# rs6376963            B      U
# rs3677817            B      U
# rs8236463            B      U
# rs6333200            B      U
# rs6298633            B      U
# rs6241531            B      D
# rs6360236            B      D
# rs3722996            B      D
# D1Mit1               B      D
# D1Mit294             B      D
# rs13475728           B      D
# rs3655978            B      D
# rs3654866            B      D
# rs3669485            B      D
# rs3713198            B      D
# rs6291839            B      D
# rs13475735           B      D
# rs3088964            B      D
# rs13475737           B      D
# rs3678179            B      D
# rs6201380            U      D
# gnf01.013.065        U      D
# CEL-1_16893098       U      D
# rs13475745           U      D
# CEL-1_18376533       U      D
# rs13475747           U      D
# rs13475748           U      D
# rs3670611            D      D
# ...                ...    ...
# CEL-X_106858553      U      U
# CEL-X_108186660      U      U
# rs6205221            D      D
# rs6387944            D      D
# rs13483992           D      D
# rs6221690            D      D
# CEL-X_121796581      D      D
# rs13484003           D      D
# rs3702256            D      D
# rs13484013           D      D
# CEL-X_125736335      D      D
# rs13484015           D      D
# rs3697198            D      D
# gnfX.116.876         D      D
# rs13484018           D      D
# rs13484024           D      D
# gnfX.118.600         U      U
# rs13484030           U      U
# rs13484060           U      U
# DXMit10              U      U
# CEL-X_143438541      U      U
# CEL-X_143595976      U      U
# rs13484097           U      U
# gnfX.141.820         U      U
# CEL-X_154048891      U      U
# CEL-X_154259201      U      U
# rs3657281            U      U
# rs13484106           U      U
# gnfX.146.867         U      U
# DXMit223             U      U
#
# [3811 rows x 96 columns]

# %% [markdown]
# ## Subtask: Replace categorical data strings with numerical encoding
#
# Let's assume the following mapping from the categorical variable to integers.
#
# |strain| value  |
# |------|--------|
# |  B   |  0     |
# |  H   |  1     |
# |  D   |  2     |
# |  U   | missing (NAN)|

# %%
# convert cell values to numerical values by applymap a encode dictionary
encode = {'B': 0, 'D': 2, 'H': 1, 'U': None}
geno_enc = geno_df.iloc[:, 3:]
geno_enc = geno_enc.applymap(encode.get)

geno_enc
# Out:
#                  BXD1  BXD2  BXD5  BXD6  BXD8  BXD9  BXD11  BXD12  BXD13  \
# Locus
# rs6269442           0     0     2   2.0     2     0      0      2      0
# rs6365999           0     0     2   2.0     2     0      0      2      0
# rs6376963           0     0     2   2.0     2     0      0      2      0
# rs3677817           0     0     2   2.0     2     0      0      2      0
# rs8236463           0     0     2   2.0     2     0      2      2      0
# rs6333200           0     0     2   2.0     2     0      2      2      0
# rs6298633           0     0     2   2.0     2     0      2      2      0
# rs6241531           0     0     2   2.0     2     0      2      2      0
# rs6360236           0     0     2   2.0     2     0      2      2      0
# rs3722996           0     0     2   2.0     2     0      2      2      0
# CEL-X_154048891      0   ...      0.0      0      2    2.0      1      2
# CEL-X_154259201      0   ...      0.0      0      2    2.0      1      2
# rs3657281            0   ...      0.0      0      2    2.0      1      2
# rs13484106           0   ...      0.0      0      2    2.0      1      2
# gnfX.146.867         0   ...      0.0      0      2    2.0      1      2
# DXMit223             0   ...      0.0      0      2    2.0      1      2
#
#                  BXD99  BXD100  BXD101  BXD102
# Locus
# rs6269442            0       0     0.0     0.0
# rs6365999            0       0     0.0     NaN
# rs6376963            0       0     0.0     NaN
# rs3677817            0       0     0.0     NaN
# rs8236463            0       0     0.0     NaN
# rs6333200            0       0     0.0     NaN
# rs6298633            0       0     0.0     NaN
# rs6241531            0       0     0.0     2.0
# rs6360236            0       0     0.0     2.0
# rs3722996            0       0     0.0     2.0
# D1Mit1               0       0     0.0     2.0
# D1Mit294             0       0     0.0     2.0
# rs13475728           0       0     0.0     2.0
# rs3655978            0       0     0.0     2.0
# rs3654866            0       0     0.0     2.0
# rs3669485            0       0     0.0     2.0
# rs3713198            0       0     0.0     2.0
# rs6291839            0       0     0.0     2.0
# rs13475735           0       0     0.0     2.0
# rs3088964            0       0     0.0     2.0
# rs13475737           0       0     0.0     2.0
# rs3678179            0       0     0.0     2.0
# rs6201380            0       0     NaN     2.0
# gnf01.013.065        0       0     NaN     2.0
# CEL-1_16893098       0       0     NaN     2.0
# rs13475745           0       0     NaN     2.0
# CEL-1_18376533       0       0     NaN     2.0
# rs13475747           0       0     NaN     2.0
# rs13475748           0       0     NaN     2.0
# rs3670611            0       0     2.0     2.0
# ...                ...     ...     ...     ...
# CEL-X_106858553      2       2     NaN     NaN
# CEL-X_108186660      2       2     NaN     NaN
# rs6205221            2       2     2.0     2.0
# rs6387944            2       2     2.0     2.0
# rs13483992           2       2     2.0     2.0
# rs6221690            2       2     2.0     2.0
# CEL-X_121796581      2       2     2.0     2.0
# rs13484003           2       2     2.0     2.0
# rs3702256            2       2     2.0     2.0
# rs13484013           2       2     2.0     2.0
# CEL-X_125736335      2       2     2.0     2.0
# rs13484015           2       2     2.0     2.0
# rs3697198            2       2     2.0     2.0
# gnfX.116.876         2       2     2.0     2.0
# rs13484018           2       2     2.0     2.0
# rs13484024           2       2     2.0     2.0
# gnfX.118.600         2       2     NaN     NaN
# rs13484030           2       2     NaN     NaN
# rs13484060           2       2     NaN     NaN
# DXMit10              1       1     NaN     NaN
# CEL-X_143438541      0       0     NaN     NaN
# CEL-X_143595976      2       0     NaN     NaN
# rs13484097           2       0     NaN     NaN
# gnfX.141.820         2       0     NaN     NaN
# CEL-X_154048891      2       0     NaN     NaN
# CEL-X_154259201      2       0     NaN     NaN
# rs3657281            2       0     NaN     NaN
# rs13484106           2       0     NaN     NaN
# gnfX.146.867         2       0     NaN     NaN
# DXMit223             2       0     NaN     NaN
#
# [3811 rows x 93 columns]

# %% [markdown]
# ## Subtask: Drop rows with unknown genotypes

# %%
geno_enc = geno_enc.dropna()
geno_enc.shape
# Out:
# (2605, 93)

# %% [markdown]
# ## Dowload categorical data from genenetworks.org

# %% [markdown]
# Most mouse phenotype data is available at genenetwork.org. This includes nearly all published phenotype measurements. You can access individual measurements from that repository using the search mask:
# 1. Go to http://gn2.genenetwork.org/
# 2. In "Select and Search" fill in:
#     1. Species: Mouse
#     2. Group: BXD
#     3. Type: Phenotypes
#     4. Dataset: BXD Published Phenotypes
# 3. Enter the trait of interest in the "Get any" field
# 4. Search
#
# For getting data on the coat color of BXD mice use "coat color" as search term and select the Record 11280 to get to the corresponding __Trait Data and Analysis__ page. There you can download the data as text file.

# %% [markdown]
# ## Load phenotype data (coat color)

# %% [markdown]
# From the source of the genotype data we know the mapping between the categorical color value
# and the actual color.
#
# |color  | value  |
# |-------|--------|
# | black |  4     |
# | grey  |  3     |
# | brown |  2     |
# | dilute|  1     |

# %%
# read in genotype data
pheno_data = '../files_day_two/sample_data.csv'
pheno_df = pd.read_csv(pheno_data, sep=',', comment='@', header=None, index_col=0, na_values='x')
pheno_df
# Out:
#             1
# 0
# C57BL/6J  4.0
# DBA/2J    1.0
# B6D2F1    4.0
# D2B6F1    4.0
# BXD1      1.0
# BXD2      4.0
# BXD5      3.0
# BXD6      3.0
# BXD8      3.0
# BXD9      1.0
# BXD11     4.0
# BXD12     3.0
# BXD13     2.0
# BXD14     4.0
# BXD15     2.0
# BXD16     3.0
# BXD18     3.0
# BXD19     3.0
# BXD20     4.0
# BXD21     1.0
# BXD22     3.0
# BXD23     4.0
# BXD24     2.0
# BXD24a    2.0
# BXD25     2.0
# BXD27     2.0
# BXD28     2.0
# BXD29     3.0
# BXD30     1.0
# BXD31     4.0
# ...       ...
# BXD191    4.0
# BXD192    2.0
# BXD193    2.0
# BXD194    2.0
# BXD195    2.0
# BXD196    2.0
# BXD197    2.0
# BXD198    3.0
# BXD199    4.0
# BXD200    2.0
# BXD201    1.0
# BXD202    3.0
# BXD203    2.0
# BXD204    4.0
# BXD205    3.0
# BXD206    1.0
# BXD207    4.0
# BXD208    3.0
# BXD209    2.0
# BXD210    4.0
# BXD211    3.0
# BXD212    3.0
# BXD213    3.3
# BXD214    3.5
# BXD215    3.0
# BXD216    1.0
# BXD217    4.0
# BXD218    4.0
# BXD219    4.0
# BXD220    1.0
#
# [202 rows x 1 columns]

# %% [markdown]
# ## Subtask: remove rows with missing data

# %%
pheno_df = pheno_df.dropna()

# %% [markdown]
# ## Convert data to numeric

# %%
pd.to_numeric(pheno_df[1])
# Out:
# 0
# C57BL/6J    4.0
# DBA/2J      1.0
# B6D2F1      4.0
# D2B6F1      4.0
# BXD1        1.0
# BXD2        4.0
# BXD5        3.0
# BXD6        3.0
# BXD8        3.0
# BXD9        1.0
# BXD11       4.0
# BXD12       3.0
# BXD13       2.0
# BXD14       4.0
# BXD15       2.0
# BXD16       3.0
# BXD18       3.0
# BXD19       3.0
# BXD20       4.0
# BXD21       1.0
# BXD22       3.0
# BXD23       4.0
# BXD24       2.0
# BXD24a      2.0
# BXD25       2.0
# BXD27       2.0
# BXD28       2.0
# BXD29       3.0
# BXD30       1.0
# BXD31       4.0
#            ...
# BXD191      4.0
# BXD192      2.0
# BXD193      2.0
# BXD194      2.0
# BXD195      2.0
# BXD196      2.0
# BXD197      2.0
# BXD198      3.0
# BXD199      4.0
# BXD200      2.0
# BXD201      1.0
# BXD202      3.0
# BXD203      2.0
# BXD204      4.0
# BXD205      3.0
# BXD206      1.0
# BXD207      4.0
# BXD208      3.0
# BXD209      2.0
# BXD210      4.0
# BXD211      3.0
# BXD212      3.0
# BXD213      3.3
# BXD214      3.5
# BXD215      3.0
# BXD216      1.0
# BXD217      4.0
# BXD218      4.0
# BXD219      4.0
# BXD220      1.0
# Name: 1, Length: 199, dtype: float64

# %% [markdown]
# # Association tests between variant(s) and categorical phenotype
# We will first start testing SNPs for their association with an easily characterizable phenotype: coat color. As you could see in the slides, BXD mice come in different colors (black, brown, dilute) and as you know, hair color is heritable. In this task you will thus try to find candidate genes that are involved in coat color determination in the mouse population.

# %% [markdown]
# Note: Nearly all variability in BXD mice has been associated with three genes: _Tyrp1_(brown, chr 4), _Myo5a_ (dilute, chr 9) and _Asip_ (non-agouti, i.e. one color) ([PMC2736153](http://www.ncbi.nlm.nih.gov/pmc/articles/PMC2736153)). We will now check if we see this association using the 3700 SNPs in our genotype.

# %% [markdown]
# ## Task: Perfom association test for a single SNP using $\chi^2$ test and odds ratio

# %% [markdown]
# ### Subtask: Extract row of a single SNP (e.g. rs6232550)

# %%
snp = geno_enc.loc['rs6232550']
geno_enc
# Out:
#                  BXD1  BXD2  BXD5  BXD6  BXD8  BXD9  BXD11  BXD12  BXD13  \
# Locus
# rs6269442           0     0     2   2.0     2     0      0      2      0
# rs6241531           0     0     2   2.0     2     0      2      2      0
# rs6360236           0     0     2   2.0     2     0      2      2      0
# rs3722996           0     0     2   2.0     2     0      2      2      0
# D1Mit1              0     0     2   2.0     2     0      2      2      0
# D1Mit294            0     0     2   2.0     2     0      2      2      0
# rs13475728          0     0     2   2.0     2     0      2      2      0
# rs3655978           0     0     0   2.0     2     0      2      2      0
# rs3654866           0     0     0   2.0     2     0      2      2      0
# rs3669485           0     0     0   2.0     2     0      2      2      0
# rs3713198           0     0     0   2.0     2     0      2      2      0
# rs6291839           0     0     0   2.0     2     0      2      2      0
# rs13475735          0     0     0   2.0     2     0      2      2      0
# rs3088964           0     0     0   2.0     2     0      2      2      0
# rs13475737          0     0     0   2.0     2     0      2      2      0
# rs3678179           0     0     0   2.0     2     0      2      2      0
# rs3670611           2     0     0   2.0     2     0      2      2      0
# rs6404446           2     0     0   2.0     2     0      2      2      0
# gnf01.018.340       2     0     0   2.0     2     0      2      2      0
# rs6253968           2     0     0   2.0     2     0      2      2      0
# rs3711079           2     0     0   2.0     2     0      2      2      0
# mCV23695025         2     0     0   2.0     2     0      2      2      0
# rs13475762          2     0     0   2.0     2     0      2      2      0
# rs6316488           2     0     0   2.0     2     0      2      2      0
# rs3659806           2     0     0   2.0     2     0      2      2      0
# rs13475765          2     0     0   2.0     2     0      2      2      0
# rs4222215           2     0     0   2.0     2     0      2      2      0
# rs3677683           2     0     0   2.0     2     0      2      2      0
# rs3713281           2     0     0   2.0     2     0      2      2      0
# rs6384194           2     0     0   2.0     2     0      0      2      0
# rs3711079            0       0     2.0     2.0
# mCV23695025          0       0     2.0     2.0
# rs13475762           0       0     2.0     2.0
# rs6316488            0       0     2.0     2.0
# rs3659806            0       0     2.0     2.0
# rs13475765           0       0     2.0     2.0
# rs4222215            0       0     2.0     2.0
# rs3677683            0       0     0.0     0.0
# rs3713281            0       0     0.0     0.0
# rs6384194            0       0     0.0     0.0
# ...                ...     ...     ...     ...
# rs13483769           2       0     2.0     0.0
# rs13483770           2       2     0.0     2.0
# gnfX.044.260         2       2     0.0     2.0
# rs13483785           2       2     0.0     2.0
# rs13483786           2       2     0.0     2.0
# rs13483822           2       0     0.0     0.0
# DXMit1               2       0     0.0     0.0
# rs13483823           2       0     0.0     0.0
# rs13483824           2       0     0.0     0.0
# CEL-X_71104123       2       0     0.0     0.0
# CEL-X_71438949       2       0     0.0     0.0
# rs13483864           2       0     0.0     0.0
# rs13483868           1       0     0.0     0.0
# rs13483805           1       0     0.0     0.0
# gnfX.076.619         1       0     0.0     0.0
# rs13483881           1       0     0.0     0.0
# rs6205221            2       2     2.0     2.0
# rs6387944            2       2     2.0     2.0
# rs13483992           2       2     2.0     2.0
# rs6221690            2       2     2.0     2.0
# CEL-X_121796581      2       2     2.0     2.0
# rs13484003           2       2     2.0     2.0
# rs3702256            2       2     2.0     2.0
# rs13484013           2       2     2.0     2.0
# CEL-X_125736335      2       2     2.0     2.0
# rs13484015           2       2     2.0     2.0
# rs3697198            2       2     2.0     2.0
# gnfX.116.876         2       2     2.0     2.0
# rs13484018           2       2     2.0     2.0
# rs13484024           2       2     2.0     2.0
#
# [2605 rows x 93 columns]

# %% [markdown]
# ### Subtask: Remove all non-strain genotye columns

# %%
# Done before

# %% [markdown]
# ### Subtask: Combine SNP data with phenotype data
# hint: it might be necessary to transpose the row, depending on what format is has (not necessary for a pandas Series)

# %%
snp = pd.to_numeric(snp)

# %% [markdown]
# ### Subtask: Check that the merging worked

# %%
joined = pheno_df.join(snp, how='inner')
joined
joined.shape
# Out:
# (90, 2)

# %% [markdown]
# ### Subtask: Plot relationship between genotye and phenotype

# %% [markdown]
# you can use a scatter plot, but equal values will occlude each other <br>
# hint: add a jitter by adding a random sample from [-x,x] for some x < 0.5 to each value

# %%
sns.regplot(x=joined['rs6232550'], y=joined[1])

# %% [markdown]
# ### Subtask: Create contingency table for a D-dominant inheritance model of black coat color and SNP rs6232550
# Tip: pandas' crosstab functionality may be helpful here and the [reshaping/crosstab documentation](http://pandas-docs.github.io/pandas-docs-travis/reshaping.html) as illustrated in [this tutorial](http://wesmckinney.com/blog/contingency-tables-and-cross-tabulations-in-pandas/) may be helpful.

# %%
con_table = pd.crosstab(joined.iloc[:,0] == 4, joined.iloc[:,1] == 2)
con_table
# Out:
# rs6232550  False  True
# 1
# False         33     38
# True          12      7

# %% [markdown]
# ### Subtask: Perform $\chi^2$ square test for independence on the contingency table

# %%
chi2, p, dof, ex = chi2_contingency(con_table, correction=False)
p
# Out:
# 0.19653975995934853

# %% [markdown]
# ### Subtask: Write function to calculate odds ratio from a contingency table

# %%
oddsratio, pvalue = stats.fisher_exact(con_table)

# %% [markdown]
# ## Task: extend statistical method for a penetrance model in which increasing numbers of A alleles confer a trend in risk (e.g. additive or dominant)

# %% [markdown]
# While you can model most of the penetrance models described in the lecture in a 2x2 contingency table and thus perform a $\chi^2$ test with one degree of freedom, it may sometimes be useful to consider the full complexity of a genotype contigency table considering all three possible genotypes instead of just two (even though the latter has larger statistical power). Apart from a $\chi^2$ test with two degrees of freedom, the Cochran–Armitage trend test is commonly used in genetic association tests as this has often larger statistical power. In this case, if the exact model of penetrance is not known, an additive approach is often used.
#
# You can read more about basic statistical approaches in genetic association tests in the following paper:
#
# __G. Clarke et al.
# [Basic statistical analysis in genetic case-control studies](http://www.nature.com/nprot/journal/v6/n2/full/nprot.2010.182.html)__,
# Nat. Protocols, 2011/02,
# http://dx.doi.org/10.1038/nprot.2010.182

# %% [markdown]
# ### Subtask: Given the data you have, could you calculate this type of statistic for your data?
#
# * If yes, please implement the creation of a contingency table and the test.
# * If no, please explain why.

# %%
# If I remember correctly there were not many heterozygote alleles present in the data so it would not be very
# exciting to do such a test although one could implement it

# %% [markdown]
# ## Task: Refactor previous analysis steps into a function and apply to all SNPs
#
# Things to consider:
# * What information is needed as input in each round?
# * Do you want to support $\chi^2$ and Cochran–Armitage test?
# * What information as output is needed?
# * Should multiple inheritance models be included?
# * Should the user get to chose which hair color to test?

# %%
oddsratios = []
pvalues = []
snp_ids = []


for i in range(0,len(geno_enc)):
    
    # Store SNP IDs and genotype data
    snp_ids.append(geno_enc.index[i])
    snp = geno_enc.iloc[i]
    snp = pd.to_numeric(snp)
    
    # join with phenotype data
    joined = pheno_df.join(snp, how='inner')
    
    # calculate contigency table and get pvalue with fishers_exact 
    con_table = pd.crosstab(joined.iloc[:,0] == 4, joined.iloc[:,1] == 2)
    chi2, p, dof, ex = chi2_contingency(con_table, correction=False)
    oddsratio, pvalue = stats.fisher_exact(con_table)
    
    # Append to list of oddsratios and pvalues
    oddsratios.append(oddsratio)
    pvalues.append(p)
    
print(len(oddsratios))
print(len(pvalues))
print(len(snp_ids))

# Make DataFrame of data
frame = pd.DataFrame(
    {'ID': snp_ids,
     'pvalues': pvalues,
     'oddsratio': oddsratios
    }).set_index('ID')
# Out:
# 2605
# 2605
# 2605

# %%
frame
# Out:
#                  oddsratio   pvalues
# ID
# rs6269442         0.128028  0.003152
# rs6241531         0.344086  0.072565
# rs6360236         0.290196  0.035427
# rs3722996         0.290196  0.035427
# D1Mit1            0.259259  0.020874
# D1Mit294          0.274286  0.027342
# rs13475728        0.274286  0.027342
# rs3655978         0.748052  0.577309
# rs3654866         0.748052  0.577309
# rs3669485         0.707071  0.505417
# rs3713198         0.707071  0.505417
# rs6291839         0.707071  0.505417
# rs13475735        0.707071  0.505417
# rs3088964         0.748052  0.577309
# rs13475737        0.748052  0.577309
# rs3678179         0.600000  0.333819
# rs3670611         0.697500  0.485624
# rs6404446         0.563636  0.269370
# gnf01.018.340     0.563636  0.269370
# rs6253968         0.502165  0.184047
# rs3711079         0.502165  0.184047
# mCV23695025       0.452083  0.130768
# rs13475762        0.452083  0.130768
# rs6316488         0.446281  0.119413
# rs3659806         0.446281  0.119413
# rs13475765        0.395257  0.073033
# rs4222215         0.395257  0.073033
# rs3677683         0.448718  0.137758
# rs3713281         0.448718  0.137758
# rs6384194         0.347222  0.057970
# ...                    ...       ...
# rs13483769        0.895833  0.836754
# rs13483770        1.466667  0.460430
# gnfX.044.260      1.230000  0.689437
# rs13483785        1.433692  0.485624
# rs13483786        1.433692  0.485624
# rs13483822        0.752137  0.604366
# DXMit1            0.708791  0.530356
# rs13483823        0.708791  0.530356
# rs13483824        0.668435  0.461801
# CEL-X_71104123    0.668435  0.461801
# CEL-X_71438949    0.668435  0.461801
# rs13483864        0.668435  0.461801
# rs13483868        0.548469  0.291823
# rs13483805        0.548469  0.291823
# gnfX.076.619      0.582011  0.343491
# rs13483881        0.582011  0.343491
# rs6205221         1.354167  0.557356
# rs6387944         1.279461  0.633447
# rs13483992        1.279461  0.633447
# rs6221690         1.142857  0.796180
# CEL-X_121796581   1.142857  0.796180
# rs13484003        1.263514  0.653642
# rs3702256         1.263514  0.653642
# rs13484013        1.194079  0.733857
# CEL-X_125736335   1.194079  0.733857
# rs13484015        1.065625  0.903197
# rs3697198         1.065625  0.903197
# gnfX.116.876      0.895349  0.832968
# rs13484018        0.949405  0.921013
# rs13484024        0.949405  0.921013
#
# [2605 rows x 2 columns]

# %%
# Plot pvalues as histogram and get excpected plot (uniformly distributed)
plt.hist(frame['pvalues'])
# Out:
# (array([474., 261., 250., 273., 238., 219., 201., 209., 240., 240.]),
#  array([4.26376382e-09, 9.90727853e-02, 1.98145566e-01, 2.97218347e-01,
#         3.96291129e-01, 4.95363910e-01, 5.94436691e-01, 6.93509472e-01,
#         7.92582253e-01, 8.91655034e-01, 9.90727815e-01]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### Subtask: Create Manhattan Plot of  $-\log_{10}(\text{P-value})$ vs chromosome position
# A Manhattan plot, named after its resemblance to the skyline of Manhattan, is commonly used to plot the p-value obtained for individual association tests for each SNP compared to the SNP's position on the genome as shown in the example below.
#
# Technically, a Manhattan plot is a scatter plot of genome position (for each chromosome) vs the negative logarithm of the p-value.

# %% [markdown]
# Try to approximate the following plot as closely as possible:

# %% [markdown]
# <img src='Manhattan.png'>

# %%
geno_df

# Create dataframe with chromosom information and MB info
frame_chrom_mb = frame.join(geno_df['Chr'], how='inner')
frame_chrom_mb = frame_chrom_mb.join(geno_df['Mb'], how='inner')

# Make sure that the MB is increasing through all chromosomes to get a continous x-scale for the plot
offsets = frame_chrom_mb.groupby('Chr',sort=False).Mb.max().cumsum()
offsets -= offsets.loc['1']
mb = geno_df.apply(lambda x: x.Mb + offsets.loc[x.Chr], axis=1)

frame_chrom_mb.insert(2, 'absMB', mb)

# Plot the absolute MB scale vs. pvalues for each chromosome
plt.subplots(figsize=(20,10))
sns.regplot(x=frame_chrom_mb['absMB'], y=-np.log10(frame_chrom_mb['pvalues']), fit_reg=False)

# %% [markdown]
# ### Subtask: If you have time, try to implement alternative inheritance models

# %%
frame_chrom_mb['pvalues']
# Out:
# rs6269442          0.003152
# rs6241531          0.072565
# rs6360236          0.035427
# rs3722996          0.035427
# D1Mit1             0.020874
# D1Mit294           0.027342
# rs13475728         0.027342
# rs3655978          0.577309
# rs3654866          0.577309
# rs3669485          0.505417
# rs3713198          0.505417
# rs6291839          0.505417
# rs13475735         0.505417
# rs3088964          0.577309
# rs13475737         0.577309
# rs3678179          0.333819
# rs3670611          0.485624
# rs6404446          0.269370
# gnf01.018.340      0.269370
# rs6253968          0.184047
# rs3711079          0.184047
# mCV23695025        0.130768
# rs13475762         0.130768
# rs6316488          0.119413
# rs3659806          0.119413
# rs13475765         0.073033
# rs4222215          0.073033
# rs3677683          0.137758
# rs3713281          0.137758
# rs6384194          0.057970
#                      ...
# rs13483769         0.836754
# rs13483770         0.460430
# gnfX.044.260       0.689437
# rs13483785         0.485624
# rs13483786         0.485624
# rs13483822         0.604366
# DXMit1             0.530356
# rs13483823         0.530356
# rs13483824         0.461801
# CEL-X_71104123     0.461801
# CEL-X_71438949     0.461801
# rs13483864         0.461801
# rs13483868         0.291823
# rs13483805         0.291823
# gnfX.076.619       0.343491
# rs13483881         0.343491
# rs6205221          0.557356
# rs6387944          0.633447
# rs13483992         0.633447
# rs6221690          0.796180
# CEL-X_121796581    0.796180
# rs13484003         0.653642
# rs3702256          0.653642
# rs13484013         0.733857
# CEL-X_125736335    0.733857
# rs13484015         0.903197
# rs3697198          0.903197
# gnfX.116.876       0.832968
# rs13484018         0.921013
# rs13484024         0.921013
# Name: pvalues, Length: 2605, dtype: float64

# %% [markdown]
# ## Task: Correct for Multiple Hypothesis Testing

# %% [markdown]
# Employ one of the correction methods described in the lecture to take care of the multiple hypothesis testing.

# %%
from statsmodels.sandbox.stats.multicomp import multipletests

# %%
# Define function for later use
# frame_chrom_mb is data frame which stores the chrom and MB
# total pvalues is the huge table with all the pearsonr pvalues for each phenotype for each snp
# phenotype is the desired phenotype
def manhattan(frame_chrom_mb, total_pvalues, phenotype):
    plt.subplots(figsize=(20,10))
    sns.regplot(x=frame_chrom_mb['absMB'], y=-np.log10(total_pvalues[phenotype]), fit_reg=False)
 
    
# correct pvalues with benjamini hochberg method
rej, corrected_p, _, _ = multipletests(frame_chrom_mb['pvalues'], alpha=0.1, method='fdr_bh')

# manhattan plot again with corrected pvalues
frame_chrom_mb['rej'] = rej
frame_chrom_mb['corrected'] = corrected_p

offsets = frame_chrom_mb.groupby('Chr',sort=False).Mb.max().cumsum()

offsets -= offsets.loc['1']
mb = geno_df.apply(lambda x: x.Mb + offsets.loc[x.Chr], axis=1)

#frame_chrom_mb.insert(2, 'absMB', mb)

plt.subplots(figsize=(20,10))
sns.regplot(x=frame_chrom_mb['absMB'], y=-np.log10(frame_chrom_mb['corrected']), fit_reg=False)

# %% [markdown]
# ### Subtask: Wrap your MHT correction in a function
# Ideally, the function should allow easy access to several parameters including the target $\alpha$ and the correction method

# %%
# Function takes pvalues, alpha value and correction method 
def pval_correct(pvalues, alpha, method):
    rej, corrected_p, _, _ = multipletests(pvalues, alpha=alpha, method=method) 
    
    return rej, corrected_p

# %% [markdown]
# ### Subtask: Test if the function works as intended

# %%
pval_correct(frame_chrom_mb['pvalues'], 0.1, 'fdr_bh')
# Out:
# (array([ True, False, False, ..., False, False, False]),
#  array([0.08209868, 0.51112151, 0.38453293, ..., 0.95686702, 0.98195168,
#         0.98195168]))

# %% [markdown]
# ## Task: Identify candidate genes from identified loci

# %% [markdown]
# ### Subtask: Identify genes in region identified by significant loci (consider each chromosome separately)

# %% [markdown]
# What we identified so far are so called __quantitative trait loci__, meaning that this locus on the genome is associated with a quantitative trait. This does not mean there is directly a causal relationship between the markers identified in the association study and the phenotype. It is, however, a pointer towards the region of the genome that may be relevant for the variability in the measured trait. The genes encompassed in this region then need to be analysed further to identify viable mechanistic candidates.
#
#
#
# A good starting point for this fine grained analysis would be to look up the genes directly linked to the SNP in dbSNP  (e.g, http://www.ncbi.nlm.nih.gov/projects/SNP/snp_ref.cgi?rs=rs3674482).
#
# Most likely the high ranking SNPs will not map directly to the causal gene, but will rather be a marker for another variant in a gene in __linkage disequilibrium__ with this this SNP. We thus need to extend the search and look at other genes in the vicinity of the high ranking SNPs.
#
# You may thus want to move on the [Biomart](http://www.ensembl.org/biomart/martview/fb0e89930dcbbdb8075ca52f8b196719) to query for genes in a genomic region.
#
# A third resource you may want to check out is the [UCSC Genome Browser](http://genome.ucsc.edu/) for visual explorations as well as the [UCSC Table Browser](http://genome.ucsc.edu/cgi-bin/hgTables?hgsid=511555905_oFRLEcH1IWO1FdKyzynrsBCRMk7w) to obtain genes in a genomic region. The identifiers of proteins in the [uniprot](http://www.uniprot.org/) database are listed in the resulting table. Uniprot then can provide useful annotations of the proteins found in the search frame.
#
# Programmatic access is possible for all the services above using their REST interfaces:
#
# [UCSC](http://genomewiki.ucsc.edu/index.php/Programmatic_access_to_the_Genome_Browser)
# [Biomart](http://www.ensembl.org/info/data/biomart/biomart_restful.html)
# [Uniprot](http://www.uniprot.org/help/programmatic_access)
#
# There have been multiple attempts to make it possible to query these services using python directly. The most important packages are: <br>
# [biomart-python](https://github.com/sebriois/biomart)
#
# If you decide to search for the genes of interest based on the genome location, make sure to select the correct reference genome. The reference used for the BXD genotyping is described in the genotype description on [genenetwork.org](http://www.genenetwork.org/dbdoc/BXDGeno.html)

# %% [markdown]
# ### Subtask: Check if the locations you found match to what is known from literature about genetics of mouse coat color

# %%
# According to this paper http://www.pnas.org/content/88/20/9228.short the loci for mouse coat color is on chromosome 
# 10

# %% [markdown]
# # Association tests between variant(s) and continuous phenotype¶
# All of the phenotype data provided in the multi-omics publication is actually not categorical. We thus have to adapt our approach to use continuous data. In the lecture you learned that instead of $\chi^2$ test or logistic regression, linear regression models or correlation tests could be used.

# %% [markdown]
# ## Task: Import relevant functions from scipy

# %%
from scipy.stats import pearsonr

# %% [markdown]
# ## Task: Load Phenotype spreadsheets from paper supplement

# %%
pheno_data = '../files_day_two/aad0189_DataFileS2.xlsx'
# read in excel and remove unneccessary sheets
xls = pd.ExcelFile(pheno_data)
sheet_names = xls.sheet_names
sheet_names.remove('NEW')

data_list = []

# drop unneccessary columns
for sheet in sheet_names:
    data = pd.read_excel(xls, sheet, na_values='x',index_col="@format=column")
    for col in data.columns:
        if col.startswith(('N', 'S', 's')):
            data = data.drop(col, axis=1)
    data_list.append(data)
# make one huge dataframe    
data_frame = data_list[0].join(data_list[1:])
# Out:
# ['Body Wt & Composition',
#  'NIBP',
#  'CLAMS',
#  'OGTT',
#  'ColdTest',
#  'TSE',
#  'VO2Max',
#  'Activity Wheel',
#  'Tissue_W',
#  'Biochemistry',
#  'Hematology']

# %% [markdown]
# ## Task: Implement Pearson's r-based test for correlation in the context of our data

# %%
data_frame
geno_enc.loc['rs6232550']

# join snp to table
data_frame = data_frame.join(geno_enc.loc['rs6232550'])

# drop NA values and join
pheno_col = data_frame['CD_Sacrifice_Order_[Rank]'].dropna()
geno_col = data_frame['rs6232550'].dropna()
both = pd.concat([geno_col, pheno_col], axis=1)

# calculate pearson correlation
both = both.dropna()
stats.pearsonr(both['rs6232550'], both['CD_Sacrifice_Order_[Rank]'])
# Out:
# (-0.34171439173124896, 0.010668192603355891)

# %%
final = []
current_plist = []
df = pd.DataFrame()
# for each phenotype
for col in data_frame.columns[0:20]:
    # drop na in current phenotype
    pheno_col = data_frame[col].dropna()
    # for each SNP
    for index in geno_enc.index:
        geno_col = geno_enc.loc[index].dropna()
        compare = pd.concat([geno_col, pheno_col], axis=1)
        compare = compare.dropna()
        pearson_tupel = stats.pearsonr(compare[index], compare[col])
        current_plist.append(pearson_tupel[1])
    # in the beginning df is empty so create new dataframe    
    if df.empty:    
        df = pd.DataFrame(data={col: current_plist})
    # otherwise just append    
    else:
        df[col] = pd.Series(current_plist)
    current_plist = [] 

df
df.shape
# Out:
# (2605, 20)

# %% [markdown]
# ## Task: Plot corresponding Manhattan Plot (using your previously defined function)

# %%
df
# Out:
#       CD_Sacrifice_Order_[Rank]  HFD_Sacrifice_Order_[Rank]  \
# 0                      0.707422                    0.841666
# 1                      0.753477                    0.923862
# 2                      0.753477                    0.923862
# 3                      0.753477                    0.923862
# 4                      0.647835                    0.790330
# 5                      0.670966                    0.826423
# 6                      0.670966                    0.826423
# 7                      0.487655                    0.615463
# 8                      0.487655                    0.615463
# 9                      0.487655                    0.615463
# 10                     0.487655                    0.615463
# 11                     0.299157                    0.396618
# 12                     0.299157                    0.396618
# 13                     0.299157                    0.396618
# 14                     0.299157                    0.396618
# 15                     0.299157                    0.396618
# 16                     0.385256                    0.466980
# 17                     0.385256                    0.466980
# 18                     0.385256                    0.466980
# 19                     0.666958                    0.704688
# 20                     0.666958                    0.704688
# 21                     0.760148                    0.581232
# 22                     0.760148                    0.581232
# 23                     0.789975                    0.617127
# 24                     0.789975                    0.617127
# 25                     0.787209                    0.585471
# 26                     0.787209                    0.585471
# 27                     0.855608                    0.992280
# 28                     0.855608                    0.992280
# 29                     0.760834                    0.640836
# ...                         ...                         ...
# 2575                   0.233205                    0.369342
# 2576                   0.095134                    0.170422
# 2577                   0.081553                    0.142521
# 2578                   0.044255                    0.059043
# 2575                  0.430629
# 2576                  0.536351
# 2577                  0.609525
# 2578                  0.668935
# 2579                  0.668935
# 2580                  0.509462
# 2581                  0.509462
# 2582                  0.509462
# 2583                  0.500295
# 2584                  0.500295
# 2585                  0.526883
# 2586                  0.526883
# 2587                  0.515111
# 2588                  0.515111
# 2589                  0.419837
# 2590                  0.419837
# 2591                  0.384517
# 2592                  0.384517
# 2593                  0.384517
# 2594                  0.459346
# 2595                  0.459346
# 2596                  0.406414
# 2597                  0.406414
# 2598                  0.406414
# 2599                  0.406414
# 2600                  0.367701
# 2601                  0.367701
# 2602                  0.350460
# 2603                  0.345678
# 2604                  0.345678
#
# [2605 rows x 20 columns]

# %%
manhattan(frame_chrom_mb, df, 'CD_BodyWeight_Wk16_[g]')

# %% [markdown]
# ## Task: Correct for multiple hypothesis testing

# %%
# correct the pearson pvalues
corrected = pval_correct(df['CD_BodyWeight_Wk16_[g]'], 0.01,'fdr_bh')

# and plot again
plt.subplots(figsize=(20,10))
sns.regplot(x=frame_chrom_mb['absMB'], y=-np.log10(corrected[1]), fit_reg=False)

# %% [markdown]
# # Run association tests for all phenotypes in Biochemistry, Hematology, and Blood Pressure
# Moving now into phenotype association studies, we will now test multiple phenotypes for genetic associations. To determine how much each trait is associated with a genetic factor, we have to repeat our analyses for (ideally all) phenotypes of interest while correcting for multiple hypothesis testing. We then have to figure out which traits are the most associated.
#
# Make sure to consider significance of association as well as the effect size of the association.
#
# Which traits are most influenced by genetics?

# %% [markdown]
# ## Task: Pick a testing method from the previous tasks that is applicable for the  phenotype variable type

# %%
def pearson_corr(genotype_df, phenotype_spread, sheet):
    """
    This function runs pearsons correlation test for all phenotypes in a specified spreadsheet the pvalues
    """
    # lists/df to store
    traits = []
    snps = []
    pvalues_list = []
    pvalues_dataframe = pd.DataFrame()
    data = pd.read_excel(xls, sheet, na_values='x',index_col="@format=column")
    # for each column in sheet
    for trait in data:
        # do not consider unneccessary columns...
        if trait.startswith("@") or trait.startswith("SE") or trait.startswith("N"):
            continue
        # ...but rather the columns asociated with HFD and CD
        if (trait.startswith('CD_') or trait.startswith('HFD_')) :
            traits.append(trait)
            
    # Get SNPs
    for snp in genotype_df.index:
        snps.append(snp)
        
    # Do pearsonR test
    for trait in traits:
        pvalues_list=[]
        #for snp in snps:
            #_,pvalue = pearsonR(genotype_df,phenotype_spread,snp,sheet,trait)
            #pvalues_list.append(pvalue)
            
        # Append pvalues to data frame according to trait    
        pvalues_dataframe[trait] = pvalues_list
        
    # set index    
    pvalues_dataframe.index = snps
    return pvalues_dataframe

# This function is somehow not working anymore...we stopped there one day and now I can't get it to fix which would take
# me forever....I thought I still leave it in. So sorry!

# %% [markdown]
# ## Task: Iteratively apply functionality to all phenotypes

# %% [markdown]
# ## Task: Extract relevant information about effect size, significance, locus,...

# %% [markdown]
# ## Task: Interpret results

# %% [markdown]
# ## Task: For most interesting examples, try to identify possible candidate genes

# %% [markdown]
# ## Task: Compare your results to literature

# %% [markdown]
# ## What confounding factors may have been ignored in the current approach? How could they be incorporated?
